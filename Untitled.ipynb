# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.options.plotting.backend = "plotly"

# %%
data = pd.DataFrame(data=np.random.rand(4, 4) * 100000,
                                 index=["Q1", "Q2", "Q3", "Q4"],
                                 columns=["East", "West", "North", "South"])

# %%
data.index.name = "Quarters"
data.columns.name = "Region"
data
# Out:
# Region            East          West         North         South
# Quarters
# Q1        11603.979954  49070.430705  74381.445274  16669.802121
# Q2        60745.023289  38611.521609  57335.739987  32593.979529
# Q3        93582.463925  34736.666363  83017.941150  88625.104117
# Q4        58785.251708  20261.057071  84624.188423  85514.235520

# %%
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x164118a50>,
#  <matplotlib.lines.Line2D at 0x1641525d0>,
#  <matplotlib.lines.Line2D at 0x164152850>,
#  <matplotlib.lines.Line2D at 0x164152cd0>]

# %%
data.plot.bar(barmode="group")

# %%
import pandas as pd
import numpy as np

# %%
daily_index = pd.date_range("2020-02-28", periods=4, freq="D") 
daily_index
# Out:
# DatetimeIndex(['2020-02-28', '2020-02-29', '2020-03-01', '2020-03-02'], dtype='datetime64[ns]', freq='D')

# %%
weekly_index = pd.date_range("2020-01-01", "2020-01-31", freq="W-SUN") 
weekly_index
# Out:
# DatetimeIndex(['2020-01-05', '2020-01-12', '2020-01-19', '2020-01-26'], dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.DataFrame(data=[21, 15, 33, 34],columns=["visitors"], index=weekly_index)
# Out:
#             visitors
# 2020-01-05        21
# 2020-01-12        15
# 2020-01-19        33
# 2020-01-26        34

# %%
df_ventes_aout = pd.read_excel("s3_data/August.xlsx",index_col ='transaction_date')
df_ventes_aout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8422 entries, 2019-08-01 to 2019-08-30
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  8422 non-null   object
#  1   store           8422 non-null   object
#  2   status          8422 non-null   object
#  3   plan            8422 non-null   object
#  4   contract_type   8422 non-null   object
#  5   amount          8422 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 460.6+ KB

# %%
df_ventes_aout = df_ventes_aout.sort_index()

# %%
df_ventes_aout.loc["2019-08-01":"2019-08-02", "amount"].plot()

# %%
msft = pd.read_csv("microsoft.csv",index_col="Date", parse_dates=["Date"])
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.062205
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.064427
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.065537
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.063871
# 1986-03-19    0.099826    0.100694    0.097222    0.098090    0.062760
# ...                ...         ...         ...         ...         ...
# 2020-05-20  184.809998  185.850006  183.940002  185.660004  185.660004
# 2020-05-21  185.399994  186.669998  183.289993  183.429993  183.429993
# 2020-05-22  183.190002  184.460007  182.539993  183.509995  183.509995
# 2020-05-26  186.339996  186.500000  181.100006  181.570007  181.570007
# 2020-05-27  180.199997  181.990005  176.600006  181.809998  181.809998
#
#                 Volume
# Date
# 1986-03-13  1031788800
# 1986-03-14   308160000
# 1986-03-17   133171200
# 1986-03-18    67766400
# 1986-03-19    47894400
# ...                ...
# 2020-05-20    31261300
# 2020-05-21    29119500
# 2020-05-22    20826900
# 2020-05-26    36073600
# 2020-05-27    39492600
#
# [8622 rows x 6 columns]

# %%
msft_close = msft.loc[:, ["Adj Close"]].copy()
msft_close.index = msft_close.index + pd.DateOffset(hours=16)
msft_close.head(2)
# Out:
#                      Adj Close
# Date
# 1986-03-13 16:00:00   0.062205
# 1986-03-14 16:00:00   0.064427

# %%
msft_close = msft_close.tz_localize("America/New_York")
msft_close.head(2)
# Out:
#                            Adj Close
# Date
# 1986-03-13 16:00:00-05:00   0.062205
# 1986-03-14 16:00:00-05:00   0.064427

# %%
msft_close = msft_close.tz_convert("UTC")
msft_close.head(2)
# Out:
#                            Adj Close
# Date
# 1986-03-13 21:00:00+00:00   0.062205
# 1986-03-14 21:00:00+00:00   0.064427

# %%
returns = np.log(msft_close / msft_close.shift(1))
returns = returns.rename(columns={"Adj Close": "returns"})
returns.head()
# Out:
#                             returns
# Date
# 1986-03-13 21:00:00+00:00       NaN
# 1986-03-14 21:00:00+00:00  0.035097
# 1986-03-17 21:00:00+00:00  0.017082
# 1986-03-18 21:00:00+00:00 -0.025749
# 1986-03-19 21:00:00+00:00 -0.017547

# %%
returns.plot.hist()

# %%
msft19 = msft.loc["2019", ["Adj Close"]].copy()
msft19.loc[:, "25day average"] = msft19["Adj Close"].rolling(25).mean()
msft19.plot()
